# %%
# importing requried libraries 
import numpy as np
import  IPython
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
#data collection process
#read the excel file
ds=pd.read_excel("C:/Users/Admin/Desktop/My project/Elgi/US Sales Product.xlsx")
ds
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
#                  Order Date                        Purchase Address
# ...

# %%
#for showing the features 
ds.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
#describe the data between the Quantity Ordered and Price Each
ds[['Quantity Ordered', 'Price Each']].describe()
# Out:
#        Quantity Ordered     Price Each
# count     185950.000000  185950.000000
# mean           1.124383     184.399735
# std            0.442793     332.731330
# min            1.000000       2.990000
# 25%            1.000000      11.950000
# 50%            1.000000      14.950000
# 75%            1.000000     150.000000
# max            9.000000    1700.000000

# %%
msno.bar(ds)
# Out:
# <AxesSubplot:>

# %%
#information about dataset
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.5+ MB

# %%
#data cleaning process  
#checking null values 
ds.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
#checking null values(Percentage bases)
percent_missing = (ds.isnull().sum() / len(ds) * 100).round(2)
ds_missing = pd.DataFrame({'% of Missing Values' :percent_missing})
ds_missing
# Out:
#                   % of Missing Values
# Order ID                          0.0
# Product                           0.0
# Quantity Ordered                  0.0
# Price Each                        0.0
# Order Date                        0.0
# Purchase Address                  0.0

# %%
#coverting the dataset excel into csv format
ds=pd.read_excel("C:/Users/Admin/Desktop/My project/Elgi/US Sales Product.xlsx")
ds.to_csv("CsvFile.csv", index=None, header=True)
df=ds.copy(deep="True")
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
#                  Order Date                        Purchase Address
# ...

# %%
# information about dataset(csv)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.5+ MB

# %%
# total rows and columns
df.shape
# Out:
# (185950, 6)

# %%
df=df.dropna(how='all')
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
#                  Order Date                        Purchase Address
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
categorical =df[['Order ID','Product']].columns 
for col in categorical:
    print('{} : {} unique value(s)'.format(col, df[col].nunique()))
# Out:
# Order ID : 178437 unique value(s)
# Product : 19 unique value(s)

# %%
df['Product'].unique()
# Out:
# array(['iPhone', 'Lightning Charging Cable', 'Wired Headphones',
#        '27in FHD Monitor', 'AAA Batteries (4-pack)',
#        '27in 4K Gaming Monitor', 'USB-C Charging Cable',
#        'Bose SoundSport Headphones', 'Apple Airpods Headphones',
#        'Macbook Pro Laptop', 'Flatscreen TV', 'Vareebadd Phone',
#        'AA Batteries (4-pack)', 'Google Phone', '20in Monitor',
#        '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer',
#        'LG Washing Machine'], dtype=object)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address
# ...

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Hour'] =df['Order Date'].dt.hour
df['Minute'] =df['Order Date'].dt.minute

# %%
df['Sales Revenue'] = df['Price Each'] * df['Quantity Ordered']
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
# ...

# %%
city =df['Purchase Address'].str.split(",",expand=True)[1]
city
# Out:
# 0                 Boston
# 1               Portland
# 2          San Francisco
# 3            Los Angeles
# 4                 Austin
#                ...
# 185945     San Francisco
# 185946       Los Angeles
# 185947           Seattle
# 185948            Dallas
# 185949       Los Angeles
# Name: 1, Length: 185950, dtype: object

# %%
df['City'] = city
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
# ...

# %%
df.shape
# Out:
# (185950, 12)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Year', 'Month', 'Hour', 'Minute', 'Sales Revenue',
#        'City'],
#       dtype='object')

# %%
df['Year'].unique()
# Out:
# array([2019, 2020], dtype=int64)

# %%
print(df['Year'].value_counts())
# Out:
# 2019    185916
# 2020        34
# Name: Year, dtype: int64

# %%
df= df[df.Year != 2020]
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable                 1       14.95
# 185946    319667       AA Batteries (4-pack)                 2        3.84
# 185947    319668             Vareebadd Phone                 1      400.00
# 185948    319669            Wired Headphones                 1       11.99
# 185949    319670  Bose SoundSport Headphones                 1       99.99
#
# ...

# %%
df.shape
# Out:
# (185916, 12)

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185916 entries, 0 to 185949
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185916 non-null  int64
#  1   Product           185916 non-null  object
#  2   Quantity Ordered  185916 non-null  int64
#  3   Price Each        185916 non-null  float64
#  4   Order Date        185916 non-null  datetime64[ns]
#  5   Purchase Address  185916 non-null  object
#  6   Year              185916 non-null  int64
#  7   Month             185916 non-null  int64
#  8   Hour              185916 non-null  int64
#  9   Minute            185916 non-null  int64
#  10  Sales Revenue     185916 non-null  float64
#  11  City              185916 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 18.4+ MB

# %%
n = df.nunique(axis=0)
print("Number of unique values in each column for 2019 data:\n",n)
# Out:
# Number of unique values in each column for 2019 data:
#  Order ID            178406
# Product                 19
# Quantity Ordered         9
# Price Each              17
# Order Date          142366
# Purchase Address    140768
# Year                     1
# Month                   12
# Hour                    24
# Minute                  60
# Sales Revenue           54
# City                     9
# dtype: int64

# %%
#total number of sales
total_sales_by_year = df.groupby('Year').agg({'Quantity Ordered' : 'sum', 'Sales Revenue' : 'sum'})
total_sales_by_year
# Out:
#       Quantity Ordered  Sales Revenue
# Year
# 2019            209038    34483365.68

# %%
product_sales = df.groupby('Product').agg({'Quantity Ordered' : 'sum', 'Price Each' : 'mean', 'Sales Revenue' : 'sum'})
print('\n Quantity Ordered, Price Each, and Sales Revenue By Product')
product_sales
# Out:
#  Quantity Ordered, Price Each, and Sales Revenue By Product
#                             Quantity Ordered  Price Each  Sales Revenue
# Product
# 20in Monitor                            4126      109.99      453818.74
# 27in 4K Gaming Monitor                  6243      389.99     2434707.57
# 27in FHD Monitor                        7547      149.99     1131974.53
# 34in Ultrawide Monitor                  6199      379.99     2355558.01
# AA Batteries (4-pack)                  27635        3.84      106118.40
# AAA Batteries (4-pack)                 31012        2.99       92725.88
# Apple Airpods Headphones               15657      150.00     2348550.00
# Bose SoundSport Headphones             13454       99.99     1345265.46
# Flatscreen TV                           4818      300.00     1445400.00
# Google Phone                            5531      600.00     3318600.00
# LG Dryer                                 646      600.00      387600.00
# ...

# %%
plt.figure(figsize = (20, 8))
sns.barplot(x = product_sales.index, y = product_sales['Quantity Ordered'], data = product_sales, palette = 'bright')
plt.title('Ordered Products', fontsize = 25, weight = 'bold')
plt.xlabel('Product', weight = 'bold', fontsize=25)
degrees = 60
plt.xticks(fontsize=14,rotation =90,weight = 'bold')
plt.yticks(fontsize=14,weight = 'bold')
plt.ylabel('Quantity Ordered', weight = 'bold',fontsize=25);

# %%
df_Measure = df[["Quantity Ordered","Sales Revenue"]].describe() 
print("\n Statistical Measure Sales product  Data")
df_Measure
# Out:
#  Statistical Measure Sales product  Data
#        Quantity Ordered  Sales Revenue
# count     185916.000000  185916.000000
# mean           1.124368     185.478203
# std            0.442749     332.911130
# min            1.000000       2.990000
# 25%            1.000000      11.950000
# 50%            1.000000      14.950000
# 75%            1.000000     150.000000
# max            9.000000    3400.000000

# %%
df.corr()
# Out:
#                   Order ID  Quantity Ordered  Price Each  Year     Month  \
# Order ID          1.000000          0.000654   -0.002912   NaN  0.605008
# Quantity Ordered  0.000654          1.000000   -0.148267   NaN -0.002113
# Price Each       -0.002912         -0.148267    1.000000   NaN -0.004262
# Year                   NaN               NaN         NaN   NaN       NaN
# Month             0.605008         -0.002113   -0.004262   NaN  1.000000
# Hour              0.001824         -0.002135    0.001812   NaN -0.001987
# Minute           -0.002265          0.001174   -0.002157   NaN -0.002150
# Sales Revenue    -0.003008         -0.139417    0.999203   NaN -0.004371
#
#                       Hour    Minute  Sales Revenue
# Order ID          0.001824 -0.002265      -0.003008
# Quantity Ordered -0.002135  0.001174      -0.139417
# Price Each        0.001812 -0.002157       0.999203
# Year                   NaN       NaN            NaN
# ...

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df[["Quantity Ordered","Price Each","Month","Hour","Minute","Sales Revenue"]].corr(),
                 annot=True, cmap="Purples", linewidths=0.006, linecolor="Black")
plt.title("US Sales Data Correlation",fontsize=25, pad=20)
plt.xticks(fontsize=9, rotation=55)
plt.yticks(fontsize=9);

# %%
df.corr()['Sales Revenue'].sort_values(ascending=False)
# Out:
# Sales Revenue       1.000000
# Price Each          0.999203
# Hour                0.001764
# Minute             -0.002158
# Order ID           -0.003008
# Month              -0.004371
# Quantity Ordered   -0.139417
# Year                     NaN
# Name: Sales Revenue, dtype: float64

# %%
avg_month_sales = df.groupby('Month').agg({'Sales Revenue' : 'mean'}).add_suffix("$")
print('\n Average Sales Revenue by Month')
avg_month_sales
# Out:
#  Average Sales Revenue by Month
#        Sales Revenue$
# Month
# 1          189.900462
# 2          183.049226
# 3          185.365373
# 4          189.751797
# 5          187.239245
# 6          188.472516
# 7          184.096895
# 8          182.003836
# 9          184.326141
# 10         185.273029
# 11         185.420563
# 12         181.933947

# %%
plt.rcParams['figure.figsize']=(10,5)
avg_month_sales.plot(kind='bar', color='blue')
plt.title('Average Sales Revenue by Month', weight='bold', fontsize=15, pad=15)
plt.ylim(100, 250)
plt.ylabel("(Average) Sales Revenue (US$)", weight='bold')
plt.xlabel('Month', weight='bold');

# %%
total_month_sales = df.groupby('Month',as_index=False).agg({'Quantity Ordered':'sum', 'Sales Revenue':'sum'})
print('Total Sales by Month')
# Out:
# Total Sales by Month

# %%
plt.rcParams['figure.figsize']=(8,4)
ay=sns.barplot(x="Month",y='Sales Revenue', data=total_month_sales, color='orange')
plt.title('Total Sales by Month', weight='bold', fontsize=15, pad=15)
plt.ylabel('Sales Revenue($)', weight='bold')
plt.xlabel('Month', weight='bold')
ylabels = ['{:,.1f}'.format(y) + ' M' for y in ay.get_yticks()/1000000]
ay.set_yticks(ay.get_yticks())  
ay.set_yticklabels(ylabels);

# %%
citywise_sales = df.groupby('City',as_index=False).agg({'Quantity Ordered':'sum', 'Sales Revenue':'sum'})
print('Total Sales by City')
citywise_sales
# Out:
# Total Sales by City
#              City  Quantity Ordered  Sales Revenue
# 0         Atlanta             16602     2795498.58
# 1          Austin             11151     1819081.77
# 2          Boston             22524     3660315.12
# 3          Dallas             16728     2766260.45
# 4     Los Angeles             33288     5451570.81
# 5   New York City             27916     4662976.81
# 6        Portland             14051     2320337.62
# 7   San Francisco             50226     8259719.03
# 8         Seattle             16552     2747605.49

# %%
Monthly_ordered  = df.groupby(['Product','Month']).agg({'Quantity Ordered' : 'sum', 'Sales Revenue':'sum'}).reset_index()
Monthly_ordered
# Out:
#           Product  Month  Quantity Ordered  Sales Revenue
# 0    20in Monitor      1               278       30577.22
# 1    20in Monitor      2               293       32227.07
# 2    20in Monitor      3               321       35306.79
# 3    20in Monitor      4               379       41686.21
# 4    20in Monitor      5               328       36076.72
# ..            ...    ...               ...            ...
# 223        iPhone      8               454      317800.00
# 224        iPhone      9               484      338800.00
# 225        iPhone     10               671      469700.00
# 226        iPhone     11               637      445900.00
# 227        iPhone     12               775      542500.00
#
# [228 rows x 4 columns]

# %%
Monthly_ordered.loc[Monthly_ordered['Product'] == '20in Monitor'].plot(x='Month',y='Quantity Ordered', marker = 'o', ms = 10, mec = 'r')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.rcParams['figure.figsize']=(10,4)
ax = sns.barplot(x='Sales Revenue',y='City',hue='Sales Revenue', data=citywise_sales.sort_values('Sales Revenue', ascending=False))
plt.title('Total Sales by City', weight='bold', fontsize=15, pad=15)
plt.ylabel('City', weight='bold')
plt.xlabel('Sales Revenue(US$)', weight='bold')

xlabels = ['{:,.1f}'.format(y) + ' M' for y in ax.get_xticks()/1000000]
ax.set_xticks(ax.get_xticks())  
ax.set_xticklabels(xlabels);

# %%
product_sales = df.groupby('Product',as_index=False).agg({'Quantity Ordered':'sum'}).sort_values('Quantity Ordered', ascending=False)
product_sales
# Out:
#                        Product  Quantity Ordered
# 5       AAA Batteries (4-pack)             31012
# 4        AA Batteries (4-pack)             27635
# 15        USB-C Charging Cable             23971
# 12    Lightning Charging Cable             23211
# 17            Wired Headphones             20553
# 6     Apple Airpods Headphones             15657
# 7   Bose SoundSport Headphones             13454
# 2             27in FHD Monitor              7547
# 18                      iPhone              6847
# 1       27in 4K Gaming Monitor              6243
# 3       34in Ultrawide Monitor              6199
# 9                 Google Phone              5531
# 8                Flatscreen TV              4818
# 13          Macbook Pro Laptop              4727
# 14             ThinkPad Laptop              4128
# 0                 20in Monitor              4126
# 16             Vareebadd Phone              2067
# 11          LG Washing Machine               666
# ...

# %%
plt.rcParams['figure.figsize']=(10,5)
q5 = sns.barplot(x='Quantity Ordered',y='Product', data=product_sales.sort_values('Quantity Ordered', ascending=False), 
                 color='Yellow')
plt.title('Quantity Ordered by Product', weight='bold', fontsize=15, pad=15)
plt.xlabel('Quantity Ordered', weight='bold')
plt.ylabel('Product', weight='bold');

# %%
product_sales = df.groupby('Product',as_index=False).agg({'Quantity Ordered':'sum', 'Sales Revenue': 'sum'}).sort_values('Quantity Ordered', ascending=False)
product_sales=product_sales.set_index("Product")
product_sales
# Out:
#                             Quantity Ordered  Sales Revenue
# Product
# AAA Batteries (4-pack)                 31012       92725.88
# AA Batteries (4-pack)                  27635      106118.40
# USB-C Charging Cable                   23971      286453.45
# Lightning Charging Cable               23211      347004.45
# Wired Headphones                       20553      246430.47
# Apple Airpods Headphones               15657     2348550.00
# Bose SoundSport Headphones             13454     1345265.46
# 27in FHD Monitor                        7547     1131974.53
# iPhone                                  6847     4792900.00
# 27in 4K Gaming Monitor                  6243     2434707.57
# 34in Ultrawide Monitor                  6199     2355558.01
# Google Phone                            5531     3318600.00
# Flatscreen TV                           4818     1445400.00
# Macbook Pro Laptop                      4727     8035900.00
# ...

# %%
SalesbyHour = df.groupby(by = 'Hour').agg({'Quantity Ordered':'sum'},inplace = True)
SalesbyHour.rename(columns = {'Quantity Ordered':'OrderbyHour'}, inplace = True)
SalesbyHour
# Out:
#       OrderbyHour
# Hour
# 0            4412
# 1            2610
# 2            1394
# 3             922
# 4             933
# 5            1491
# 6            2810
# 7            4556
# 8            7002
# 9            9816
# 10          12308
# 11          14005
# 12          14202
# 13          13685
# 14          12362
# 15          11391
# 16          11662
# 17          12229
# 18          13802
# 19          14470
# 20          13768
# 21          12244
# 22           9899
# 23           7065

# %%
plt.figure(figsize=(12, 6))
plt.plot(SalesbyHour.index, SalesbyHour['OrderbyHour'], marker = '*', ms = 8, mec = 'm')
plt.grid(True)
plt.title('Hourly Sales', fontname='cursive', weight='bold')
plt.xlabel('Hour(day)',weight="bold", loc="center")
plt.ylabel('OrderbyHour',weight="bold", loc="center");

# %%
from itertools import combinations
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

data = df[df['Order ID'].duplicated(keep=False)]
data['Combine'] = df.groupby('Order ID',as_index=False)['Product'].transform(lambda x: ','.join(x))

pd.set_option('mode.chained_assignment', None)
data.head()
# Out:
#      Order ID                   Product  Quantity Ordered  Price Each  \
# 41     141275      USB-C Charging Cable                 1       11.95
# 42     141275          Wired Headphones                 1       11.99
# 57     141290  Apple Airpods Headphones                 1      150.00
# 58     141290     AA Batteries (4-pack)                 3        3.84
# 133    141365           Vareebadd Phone                 1      400.00
#
#              Order Date                        Purchase Address  Year  Month  \
# 41  2019-07-01 16:06:00         610 Walnut St, Austin, TX 73301  2019      7
# 42  2019-07-01 16:06:00         610 Walnut St, Austin, TX 73301  2019      7
# 57  2019-02-01 08:25:00         4 1st St, Los Angeles, CA 90001  2019      2
# 58  2019-02-01 08:25:00         4 1st St, Los Angeles, CA 90001  2019      2
# 133 2019-10-01 11:19:00  20 Dogwood St, New York City, NY 10001  2019     10
#
#      Hour  Minute  Sales Revenue            City  \
# ...

# %%
data = data[['Order ID', 'Combine']].drop_duplicates()
count = Counter()
for row in data['Combine']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1004
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 359
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
# x input
feature_cols=['Quantity Ordered','Price Each']
x=df[feature_cols]
x.head()
# Out:
#    Quantity Ordered  Price Each
# 0                 1      700.00
# 1                 1       14.95
# 2                 2       11.99
# 3                 1      149.99
# 4                 1       11.99

# %%
# y output
y=df['Sales Revenue']
y.head()
# Out:
# 0    700.00
# 1     14.95
# 2     23.98
# 3    149.99
# 4     11.99
# Name: Sales Revenue, dtype: float64

# %%
# Spliting x and y into training and testing set
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (148732, 2)
# (148732,)
# (37184, 2)
# (37184,)

# %%
#x_test.reset_index(drop=True)
x_test=pd.DataFrame(x_test)
x_test.head()
# Out:
#         Quantity Ordered  Price Each
# 142258                 1        3.84
# 84216                  1      150.00
# 55616                  2        3.84
# 54305                  2        2.99
# 28277                  1        2.99

# %%
y_test.reset_index(drop=True)
# Out:
# 0          3.84
# 1        150.00
# 2          7.68
# 3          5.98
# 4          2.99
#           ...
# 37179     14.95
# 37180    150.00
# 37181      2.99
# 37182     99.99
# 37183     99.99
# Name: Sales Revenue, Length: 37184, dtype: float64

# %%
# model fitting 
linreg=LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# interpreting a model coefficient 
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# -6.80889951226203
# [6.83165533 1.00129822]

# %%
list(zip(feature_cols, linreg.coef_))
# Out:
# [('Quantity Ordered', 6.831655327361484), ('Price Each', 1.001298217529089)]

# %%
predicted=linreg.predict(x_test)
print(predicted)
# Out:
# [  3.86774097 150.21748844  10.6993963  ...   3.01663749 100.14256459
#  100.14256459]

# %%
dfr=pd.DataFrame({'Actual':y_test, 'Predicted':predicted})
dfr.head(20)
# Out:
#         Actual   Predicted
# 142258    3.84    3.867741
# 84216   150.00  150.217488
# 55616     7.68   10.699396
# 54305     5.98    9.848293
# 28277     2.99    3.016637
# 62213     3.84    3.867741
# 130157  109.99  110.155547
# 24158    11.95   11.988270
# 134633  379.99  380.506065
# 21641     2.99    3.016637
# 92589    99.99  100.142565
# 174993   11.99   12.028321
# 67566   109.99  110.155547
# 166408   99.99  100.142565
# 148319    5.98    9.848293
# 142098   14.95   14.992164
# 171413  150.00  150.217488
# 57816    23.98   18.859977
# 141811  149.99  150.207475
# 30688     3.84    3.867741

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics

# %%
import math #calculating the square root error

# %%
print('Mean Absolute Error :',metrics.mean_absolute_error(y_test,predicted))
# Out:
# Mean Absolute Error : 1.0743080794976854

# %%
graph=dfr.head(20)

# %%
graph.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print('Mean squared Error :',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean squared Error : 8.564662052969112

# %%
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,predicted)
r2_score
# Out:
# 0.9993359831047813

# %%
Accuracy =linreg.score(x_test,y_test)*100
print("Accuracy of Linear regression is :", Accuracy)
# Out:
# Accuracy of Linear regression is : 99.93359831047813

# %%
x=int(input("en:"))
y=float(input("en:"))
a=[[x,y]]
user_test=linreg.predict(a)
print(user_test)
# Out:
# en:1
# en:3.86
# [3.88776693]

# %%
residual=(y_test-user_test).reset_index()
dfr=pd.DataFrame(residual)
dfr=dfr.set_index("index")
dfr.head()
# Out:
#         Sales Revenue
# index
# 142258      -0.047767
# 84216      146.112233
# 55616        3.792233
# 54305        2.092233
# 28277       -0.897767
